# %% [markdown]
# Q1. You want an AI model to explain, in your own words, the difference between Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI. Write a complete prompt that asks the AI to explain these four concepts as layered ideas, using one real-world example for each, in language suitable for a first-year college student.
#
# Answer:
#
# Explain the difference between Artificial Intelligence (AI), Machine Learning (ML), Deep Learning (DL), and Generative AI as connected concepts. Start with AI and then explain how ML, DL, and Generative AI fit within it. Use simple English that a first-year college student can understand. Give one real-world example for each concept and explain everything step by step.

# %% [markdown]
# Q2. Write a prompt asking an AI model to explain how it processes a user's prompt, describing the stages of tokenization, understanding context, and predicting the next tokens, using a simple analogy a non-technical person would understand.
#
# Answer:
#
# Explain how an AI model processes a user's prompt. Describe tokenization, understanding context, and predicting the next token in simple language. Use an easy real-life analogy that a non-technical person can understand. Keep the explanation clear and beginner-friendly.

# %% [markdown]
# Q3. You want to understand why an AI model does not simply "search and copy" answers from the internet. Write a prompt requesting a clear explanation of how an LLM actually generates a response, including the role of probability in choosing the next word.
#
# Answer:
#
# Explain why a Large Language Model (LLM) does not simply search the internet and copy answers. Describe how it generates responses by predicting the next word based on patterns learned during training. Also explain how probability helps the model choose the next word. Use simple language with one easy example.

# %% [markdown]
# Q4. Write a prompt asking the AI to explain what a "context window" is, why it has a limit, and what happens when a conversation exceeds that limit. Ask for the explanation to include a simple numeric example.
#
# Answer:
#
# Explain what a context window is in an AI model. Describe why it has a limit and what happens when a conversation becomes longer than the context window. Include one simple numerical example to make the idea easy to understand. Use beginner-friendly language.

# %% [markdown]
# Q5. Draft a prompt that asks the AI to compare "Training" and "Inference" side by side in a two-column format, describing what happens in each phase and when each one occurs.
#
# Answer:
#
# Compare "Training" and "Inference" in Artificial Intelligence using a two-column table. Explain what happens during each phase, when it takes place, and why each phase is important. Use simple English suitable for beginners.

# %% [markdown]
# Q6. Write two versions of a prompt asking "What is Machine Learning?"—one vague/poor version and one improved version that adds a role, an audience, and a request for a real-world example. Explain in one sentence why the second version would produce a better response.
#
# Answer:
#
# Poor Prompt:
#
# What is Machine Learning?
#
# Improved Prompt:
#
# Act as an AI teacher. Explain Machine Learning to a first-year engineering student using simple English. Include one real-world example and explain why Machine Learning is useful in everyday life. Keep the answer within 200 words.
#
# Reason:
#
# The second prompt gives the AI a clear role, audience, and instructions, so it produces a more focused and useful response.

# %% [markdown]
# Q7. Write a complete prompt using all six components of a good prompt (Role, Task, Context, Instructions, Constraints, Output Format) to ask an AI to explain "Cloud Computing" to a non-technical business owner.
#
# Answer:
#
# Role: You are an experienced IT trainer.
# Task: Explain Cloud Computing.
# Context: The audience is a non-technical business owner.
# Instructions: Explain the concept using simple words and everyday examples. Describe its benefits and common uses.
# Constraints: Avoid technical jargon and keep the explanation within 250 words.
# Output Format: Use headings and bullet points.

# %% [markdown]
# Q8. Take the vague prompt "Write something for my manager" and rewrite it as a clear, complete prompt that specifies the role, the audience, the purpose of the message, a word limit, and the tone required.
#
# Answer:
#
# Act as a professional business communication assistant. Write an email to my manager informing them that I have completed my assigned work and submitted all the required files. Keep the email within 100 words and use a polite, respectful, and professional tone.

# %% [markdown]
# Q9. Write a prompt using the Role component only, asking the AI to act as an experienced HR Manager, and then have it draft a short policy note about work-from-home guidelines.
#
# Answer:
#
# Act as an experienced HR Manager and draft a short policy note explaining the company's work-from-home guidelines. Use a professional and easy-to-understand tone.

# %% [markdown]
# Q10. Write a prompt that uses Context to help an AI understand a situation before responding: you are a final-year engineering student preparing for a job interview and need help answering "Tell me about yourself."
#
# Answer:
#
# I am a final-year engineering student preparing for my first job interview. I have learned Python, Machine Learning, and SQL, completed academic projects, and finished an internship. Based on this background, help me answer the interview question, "Tell me about yourself." Keep the answer confident, natural, and suitable for a fresher, with a length of about two minutes.

# %% [markdown]
# Q11. Write a prompt with Constraints only: ask the AI to explain "Blockchain Technology" in exactly 80 words, using no technical jargon.
#
# Answer:
#
# Explain Blockchain Technology in exactly 80 words. Do not use any technical jargon. Use simple English that a beginner can easily understand.

# %% [markdown]
# Q12. Design a reusable Prompt Template (using placeholders like [ROLE], [TASK], [CONTEXT], [INSTRUCTIONS], [CONSTRAINTS], [FORMAT]) that a new employee could reuse to ask the AI to explain any technical topic to any type of audience.
#
# Answer:
#
# Role: [ROLE]
# Task: [TASK]
# Context: [CONTEXT]
# Instructions: [INSTRUCTIONS]
# Constraints: [CONSTRAINTS]
# Output Format: [FORMAT]
#
# Explain the topic based on the above details and make sure the response matches the audience and follows all the given instructions.

# %% [markdown]
# Q13. Write a Zero-Shot prompt asking the AI to classify the following review as Positive, Negative, or Neutral, without giving it any example: "The delivery was fast, but the packaging was damaged."
#
# Answer:
#
# Classify the following customer review as Positive, Negative, or Neutral. Return only the category.
#
# Review: "The delivery was fast, but the packaging was damaged."

# %% [markdown]
# Q14. Write a One-Shot prompt that gives the AI one labeled example of classifying customer feedback into "Complaint" or "Compliment", and then asks it to classify a new piece of feedback of your choice.
#
# Answer:
#
# Example:
#
# Feedback: "The support team solved my issue quickly."
#
# Category: Compliment
#
# Now classify the following feedback as either Complaint or Compliment.
#
# Feedback: "The product arrived three days late and the box was broken."

# %% [markdown]
# Q15. Write a Few-Shot prompt that gives at least three labeled examples of classifying a sentence's tone as Formal or Informal, and then asks the AI to classify two new sentences.
#
# Answer:
#
# Example 1:
#
# Sentence: "Please submit the report by Friday."
#
# Tone: Formal
#
# Example 2:
#
# Sentence: "Hey, can you send it today?"
#
# Tone: Informal
#
# Example 3:
#
# Sentence: "Kindly attend the meeting at 10 AM."
#
# Tone: Formal
#
# Now classify the tone of these sentences:
#
# "Thanks a lot for your help!"
# "I would appreciate your response at your earliest convenience."

# %% [markdown]
# Q16. Write a prompt that uses delimiters (triple quotes, dashes, or XML-style tags) to clearly separate your instructions from a block of sample text you want summarized, and explain in one sentence why delimiters reduce confusion for the model.
#
# Answer:
#
# Summarize the following text in 5 simple bullet points.
#
# Artificial Intelligence is changing many industries by improving automation, decision-making, and customer service. Many companies use AI to save time, reduce costs, and improve accuracy.
#
# Reason: Delimiters clearly separate the instructions from the text, making it easier for the AI to understand what needs to be summarized.

# %% [markdown]
# Q17. Write a three-step prompt refinement exercise: (a) a poor prompt asking the AI to "explain databases", (b) an improved version adding audience and language style, and (c) a final version adding a word-limit constraint and a required output structure.
#
# Answer:
#
# (a) Poor Prompt
#
# Explain databases.
#
# (b) Improved Prompt
#
# Explain databases to a first-year engineering student using simple English and everyday examples.
#
# (c) Final Prompt
#
# Explain databases to a first-year engineering student using simple English. Keep the explanation within 150 words. Organize the answer using the headings: Definition, Features, Advantages, and Example.

# %% [markdown]
# Q18. Write a Role + Context combined prompt where the AI acts as a "Career Counsellor" and uses context about a student's background (choose your own details) to recommend three suitable career paths.
#
# Answer:
#
# Act as an experienced Career Counsellor. A student has completed a B.Tech in Computer Science, enjoys Python programming, has basic knowledge of Machine Learning, and likes solving problems. Based on this background, recommend three suitable career paths. Explain why each career is a good choice and list the skills needed to succeed.

# %% [markdown]
# Q19. Write a Chain-of-Thought prompt that asks the AI to solve, step by step, the following problem: a shop offers a 15% discount on a product priced at ₹3,500, and then adds 5% tax on the discounted price — what is the final amount to be paid?
#
# Answer:
#
# Solve the following problem step by step. Show all calculations clearly before giving the final answer.
#
# A product costs ₹3,500. A shop gives a 15% discount on the original price. After the discount, a 5% tax is added to the discounted price. Calculate the final amount the customer has to pay.

# %% [markdown]
# Q20. Write a Self-Consistency prompt that asks the AI to solve a distance/speed/time problem of your choice using two different approaches and then select the most reliable final answer.
#
# Answer:
#
# Solve the following problem using two different methods and compare the results. If both methods produce the same answer, provide the final answer with a short explanation of why it is reliable.
#
# A car travels 240 km at a speed of 60 km/h. How much time does it take to reach the destination?

# %% [markdown]
# Q21. Write a Step-Back prompt that first asks the AI to identify the general principle behind why two products with the same features can have very different prices, before applying that principle to a specific example.
#
# Answer:
#
# First, explain the general reasons why two products with similar features can have different prices. Discuss factors like brand value, product quality, customer service, and marketing. Then apply these ideas to compare two smartphones with similar specifications but different prices. Use simple English and real-life examples.

# %% [markdown]
# 22. Write a Prompt Decomposition sequence (at least 4 smaller prompts) that breaks the large task "Create a complete social media marketing plan for a new bakery" into smaller, manageable prompts.
#
# Answer:
#
# Prompt 1:
#
# Identify the target audience for a new bakery and describe their interests.
#
# Prompt 2:
#
# Suggest suitable social media platforms for promoting the bakery and explain why.
#
# Prompt 3:
#
# Create a one-week content calendar with daily post ideas.
#
# Prompt 4:
#
# Suggest marketing strategies, promotional offers, and ways to measure campaign success.

# %% [markdown]
# 23. Write a three-prompt Prompt Chain where the output of each prompt feeds into the next: Prompt 1 extracts key points from a long article, Prompt 2 turns those key points into a summary, and Prompt 3 turns the summary into a 5-slide presentation outline.
#
# Answer:
#
# Prompt 1:
#
# Read the article and extract the 10 most important points.
#
# Prompt 2:
#
# Using the key points extracted above, write a summary in about 150 words.
#
# Prompt 3:
#
# Using the summary above, create a 5-slide presentation outline with a title and bullet points for each slide.

# %% [markdown]
# 24. Write a Self-Reflection prompt that asks the AI to first answer a question of your choice, then review its own answer for factual errors, missing information, and unclear explanations, and finally provide an improved version.
#
# Answer:
#
# Explain the benefits of Artificial Intelligence in education. After writing your answer, review it for factual errors, missing information, and unclear explanations. Finally, improve the answer and present the revised version in simple English.

# %% [markdown]
# 25. Write a Critique-and-Revise prompt in which the AI first drafts a short apology email to a client for a delayed delivery, then critiques its own draft for tone and clarity, and finally produces a revised version.
#
# Answer:
#
# Write a short apology email to a client for a delayed product delivery. After writing the email, review it for tone, clarity, and professionalism. Point out any weaknesses and then rewrite the email with the improvements.

# %% [markdown]
# 26. Write a Text Generation prompt asking the AI to act as a professional content writer and produce a 300-word LinkedIn post announcing a new AI training program at Cambridge Infotech, aimed at working professionals.
#
# Answer:
#
# Act as a professional content writer. Write a LinkedIn post of about 300 words announcing a new AI Training Program at Cambridge Infotech for working professionals. Highlight the course benefits, practical learning, industry relevance, and encourage readers to register. Use a professional and engaging tone.

# %% [markdown]
# 27. Write a Summarization prompt that asks the AI to condense a long research article into exactly 5 bullet points, focusing only on the key findings and ignoring background information.
#
# Answer:
#
# Summarize the following research article into exactly 5 bullet points. Include only the key findings and ignore the background, introduction, and other unnecessary details. Keep each bullet short and clear.

# %% [markdown]
# 28. Write a Classification prompt that asks the AI to classify five sample customer support messages (write the five messages yourself) into "Complaint", "Inquiry", or "Feedback", and return only the category for each.
#
# Answer:
#
# Classify each customer message into Complaint, Inquiry, or Feedback. Return only the category for each message.
#
# Messages:
#
# My order has not arrived yet.
# What are your delivery charges?
# Your mobile app is very easy to use.
# I received a damaged product.
# Do you offer a student discount?

# %% [markdown]
# 29. Write an Information Extraction prompt that asks the AI to extract Name, Job Title, Years of Experience, and Key Skills from a short candidate profile you write yourself (2–3 sentences).
#
# Answer:
#
# Read the candidate profile below and extract the following information:
#
# Name
# Job Title
# Years of Experience
# Key Skills
#
# Candidate Profile:
#
# "Riya Sharma is a Data Analyst with 4 years of experience. She is skilled in Python, SQL, Power BI, and Excel. She enjoys analyzing business data and creating reports."

# %% [markdown]
# 30. Write a Translation prompt that asks the AI to translate a short paragraph about renewable energy into Hindi, while preserving technical terms and using natural, everyday language.
#
# Answer:
#
# Translate the following paragraph into Hindi. Keep technical terms such as solar energy, wind energy, and renewable energy in their commonly used form if needed. Use natural, everyday Hindi that is easy to understand.
#
# Paragraph:
#
# "Renewable energy is becoming more important because it helps reduce pollution and protects the environment. Solar energy and wind energy are clean sources of power that can meet future energy needs."

# %% [markdown]
# 31. Write a Rewriting/Transformation prompt that asks the AI to take a casual message ("hey can u pls send the report by tmrw eod, thanks") and rewrite it in three tones: Professional, Friendly, and Formal.
#
# Answer:
#
# Rewrite the following message in three different tones: Professional, Friendly, and Formal. Keep the meaning the same.
#
# Message:
# "hey can u pls send the report by tmrw eod, thanks"

# %% [markdown]
# 32. Write a Context-Based Question-Answering prompt that provides a short paragraph of background information (write 3–4 sentences about any topic) and then asks the AI to answer a specific question using only that provided context.
#
# Answer:
#
# Read the following paragraph and answer the question using only the information provided.
#
# Paragraph:
#
# "Electric vehicles (EVs) use electricity instead of petrol or diesel. They produce less pollution and are better for the environment. Many governments are encouraging people to use EVs by offering subsidies. Charging stations are also increasing in many cities."
#
# Question:
#
# Why are governments encouraging people to use electric vehicles?

# %% [markdown]
# 33. Write a prompt that asks the AI to explain the advantages of remote work in exactly 6 bullet points, with no additional explanation before or after the list.
#
# Answer:
#
# Explain the advantages of remote work in exactly 6 bullet points. Do not include any introduction, conclusion, or extra explanation before or after the list.

# %% [markdown]
# 34. Write a prompt that asks the AI to compare "Machine Learning" and "Deep Learning" in a table, with columns for Definition, Data Requirement, and Typical Use Case.
#
# Answer:
#
# Compare Machine Learning and Deep Learning in a table. Include the following columns:
#
# Definition
# Data Requirement
# Typical Use Case
#
# Use simple language that is easy for beginners to understand.

# %% [markdown]
# 35. Write a JSON-based prompt (including a defined schema with field names such as name, role, experience_years, and skills as an array) that asks the AI to extract structured candidate information from a short resume paragraph you write yourself.
#
# Answer:
#
# Read the candidate profile below and extract the information in the following JSON format.
#
# JSON Schema:
# {
#   "name": "",
#   "role": "",
#   "experience_years": "",
#   "skills": []
# }
#
# Candidate Profile:
#
# "Anjali Verma is a Software Engineer with 5 years of experience. She is skilled in Python, Java, SQL, and Git."

# %% [markdown]
# 36. Write a prompt that asks the AI to return the same candidate information as XML instead of JSON, using appropriate opening and closing tags.
#
# Answer:
#
# Read the candidate profile below and return the information in XML format using proper opening and closing tags.
#
# Candidate Profile:
#
# "Anjali Verma is a Software Engineer with 5 years of experience. She is skilled in Python, Java, SQL, and Git."

# %% [markdown]
# 37. Write a Schema-Based prompt for extracting product review data (fields: product_name, rating, sentiment, main_complaint) and explicitly instruct the AI to return null for any field it cannot determine, rather than guessing.
#
# Answer:
#
# Read the product review below and extract the following fields:
#
# product_name
# rating
# sentiment
# main_complaint
#
# Return the result in JSON format. If any field cannot be identified, return null instead of guessing.
#
# Review:
#
# "The headphones have excellent sound quality, but the battery lasts only a few hours."

# %% [markdown]
# 38. Write a prompt that combines multiple output constraints at once: classify a customer complaint into one of three fixed categories (Billing, Product, Delivery), identify the main issue, suggest a solution, and return the entire result as a single JSON object.
#
# Answer:
#
# Read the customer complaint below. Classify it into one of these categories only: Billing, Product, or Delivery. Identify the main issue, suggest a suitable solution, and return the complete result as a single JSON object.
#
# Complaint:
#
# "I received the wrong item and the replacement has not arrived yet."

# %% [markdown]
# 39. Write a prompt asking the AI to convert a plain-language business requirement ("find all customers who spent more than ₹10,000 last month") into a CSV-style output listing sample matching records, with clearly labeled columns.
#
# Answer:
#
# Convert the following business requirement into a CSV-style table with sample matching records.
#
# Requirement:
#
# "Find all customers who spent more than ₹10,000 last month."
#
# Include the columns:
#
# Customer_ID
# Customer_Name
# Total_Spent
# Month

# %% [markdown]
# 40. Write a complete code-generation prompt (Role + Language + Task + Requirements + Input + Output) asking the AI to write a Python function that checks whether a given number is a prime number, including error handling for negative numbers.
#
# Answer:
#
# Role: You are an experienced Python developer.
#
# Language: Python
#
# Task: Write a function that checks whether a given number is a prime number.
#
# Requirements:
#
# Handle negative numbers by displaying an appropriate error message.
# Use clear variable names.
# Add comments to explain the code.
# Keep the code simple and beginner-friendly.
#
# Input: A single integer entered by the user.
#
# Output: Display whether the number is prime or not, or show an error message if the input is negative.

# %% [markdown]
# 41. Write a prompt asking the AI to explain a piece of Python code (of your choice, at least 5 lines) line by line to a complete beginner, explaining both what each line does and why it is used.
#
# Answer:
#
# Explain the following Python code line by line to a complete beginner. For each line, explain what it does and why it is used. Use simple English and avoid technical terms.
#
# numbers = [10, 20, 30, 40]
# total = sum(numbers)
# average = total / len(numbers)
# print("Total:", total)
# print("Average:", average)

# %% [markdown]
# 42. Write a Debugging prompt that provides a short piece of buggy code, the exact error message it produces, and the expected output, and asks the AI to explain the cause of the error and provide corrected code.
#
# Answer:
#
# The following Python code gives an error. Explain why the error occurs, provide the corrected code, and explain the changes.
#
# Code:
#
# numbers = [1, 2, 3]
# print(numbers[5])
#
# Error Message:
#
# IndexError: list index out of range
#
# Expected Output:
#
# Print the last number in the list.

# %% [markdown]
# 43. Write a Code Optimization prompt asking the AI to improve the performance of a given Python function while preserving its exact output, and to explain the changes made using a before-and-after comparison.
#
# Answer:
#
# Improve the performance of the following Python function without changing its output. Explain the improvements using a before-and-after comparison. Keep the optimized code easy to understand.
#
# def find_even(numbers):
#     result = []
#     for num in numbers:
#         if num % 2 == 0:
#             result.append(num)
#     return result

# %% [markdown]
# 44. Write a prompt asking the AI to refactor a messy piece of code by adding proper functions, meaningful variable names, and PEP 8 formatting, without changing its final output.
#
# Answer:
#
# Refactor the following Python code by creating proper functions, using meaningful variable names, adding comments where needed, and following PEP 8 coding standards. Do not change the final output.
#
# a=[10,20,30]
# s=0
# for i in a:
#  s=s+i
# print(s)

# %% [markdown]
# 45. Write a prompt asking the AI to generate unit test cases (3 normal cases, 2 edge cases, and 2 invalid-input cases) for a function that calculates the average of a list of numbers, using Python's unittest framework.
#
# Answer:
#
# Generate unit test cases using Python's unittest framework for a function that calculates the average of a list of numbers. Include:
#
# 3 normal test cases
# 2 edge test cases
# 2 invalid input test cases
#
# Add comments explaining what each test case checks.

# %% [markdown]
# 46. Write a prompt asking the AI to convert a business requirement ("list all employees whose department is Sales and salary is above ₹60,000") into a correct SQL query, given a table named employees with columns employee_id, name, department, and salary.
#
# Answer:
#
# Convert the following business requirement into a correct SQL query.
#
# Business Requirement:
#
# "List all employees whose department is Sales and salary is above ₹60,000."
#
# Table Name: employees
#
# Columns:
#
# employee_id
# name
# department
# salary
#
# Return only the SQL query with proper formatting.

# %% [markdown]
# 47. Write a Dataset Understanding prompt asking the AI to act as a senior data analyst and describe the number of rows, columns, data types, missing values, and possible data quality issues in a dataset you describe briefly.
#
# Answer:
#
# Act as a Senior Data Analyst. I have a sales dataset with 5,000 rows and 6 columns: Order_ID, Date, Product, Region, Quantity, and Revenue. Describe the number of rows, columns, data types, missing values, and possible data quality issues. Use simple language and organize the answer with headings.

# %% [markdown]
# 48. Write a Data Cleaning prompt asking the AI to identify columns with missing values in a given dataset description and suggest the most appropriate treatment method for each.
#
# Answer:
#
# Act as a Data Analyst. A customer dataset contains the columns Name, Age, City, Email, and Salary. Some values are missing in Age, City, and Salary. Identify which columns have missing values and suggest the best data cleaning method for each column. Explain your recommendations in simple English.

# %% [markdown]
# 49. Write an Exploratory Data Analysis (EDA) prompt asking the AI to identify important patterns, outliers, and relationships between variables in a sales dataset containing Date, Product, Region, and Revenue columns.
#
# Answer:
#
# Act as a Data Analyst. Perform an Exploratory Data Analysis (EDA) on a sales dataset containing the columns Date, Product, Region, and Revenue. Identify important patterns, trends, outliers, and relationships between the variables. Suggest useful insights using simple English and present the results with headings and bullet points.

# %% [markdown]
# 50. Write a Data Visualization prompt asking the AI to suggest three appropriate charts for a dataset (state the chart type, the X-axis, the Y-axis, and the business question each chart answers) for the sales dataset above.
#
# Answer:
#
# Act as a Data Analyst. Based on the sales dataset with the columns Date, Product, Region, and Revenue, suggest three suitable charts. For each chart, mention:
#
# Chart type
# X-axis
# Y-axis
# Business question the chart answers
#
# Explain why each chart is useful in simple English.

# %% [markdown]
# 51. Write a Machine Learning Model Selection prompt that describes a dataset with a target variable of "Customer_Churn" and asks the AI to suggest suitable algorithms, why each is appropriate, key preprocessing steps, and evaluation metrics to use.
#
# Answer:
#
# Act as an experienced Machine Learning Engineer. I have a customer dataset where the target variable is Customer_Churn, which indicates whether a customer leaves the company or stays. Suggest suitable machine learning algorithms for this classification problem. Explain why each algorithm is appropriate, list the important data preprocessing steps, and recommend suitable evaluation metrics to measure model performance. Use simple English and present the answer with headings and bullet points.

# %% [markdown]
# 52. Write a Business Insight prompt asking the AI to analyze a dataset from a business perspective and identify important trends, risks, opportunities, and recommended actions, rather than just describing the numbers.
#
# Answer:
#
# Act as a Business Data Analyst. Analyze a sales dataset from a business point of view instead of simply describing the numbers. Identify important trends, business risks, growth opportunities, and provide practical recommendations that can help improve business performance. Use simple English and organize the answer with clear headings.

# %% [markdown]
# 53. Write a full Data Analysis Prompt Template (using placeholders for Role, Dataset description, Business Objective, and Tasks) that could be reused for any new dataset your team receives in the future.
#
# Answer:
#
# Role: [ROLE]
#
# Dataset Description: [DATASET_DESCRIPTION]
#
# Business Objective: [BUSINESS_OBJECTIVE]
#
# Tasks:
#
# Understand the dataset structure.
# Check data types and missing values.
# Identify data quality issues.
# Suggest suitable data cleaning methods.
# Perform Exploratory Data Analysis (EDA).
# Identify trends, patterns, and outliers.
# Recommend appropriate visualizations.
# Suggest suitable machine learning models if required.
# Provide business insights and actionable recommendations.
#
# Output Format:
#
# Dataset Overview
# Data Quality Report
# Data Cleaning Suggestions
# EDA Findings
# Visualization Recommendations
# Machine Learning Suggestions (if applicable)
# Business Insights
# Final Recommendations
