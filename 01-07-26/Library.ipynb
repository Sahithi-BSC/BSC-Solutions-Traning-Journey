# %%
# Student Library Management System

file = open("books.txt", "r")


student_id = int(input("Enter student ID: "))
book_required = input("Enter the book you want: ")



class Student:
    def __init__(self, student_id):
        self.student_id = student_id




if book_required in file.read():
    print("Book is available.")

else:
    print("Book is not available.")

file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       6 class Student:
#       7     def __init__(self, student_id):
#       8         self.student_id = student_id
#       9
# ---> 10 file = open("Books.txt", "r")
#      11
#      12 if book_required in file.read():
#      13     print("Book is available.")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Books.txt'

# %%
book_name = input("Enter the book name: ")
